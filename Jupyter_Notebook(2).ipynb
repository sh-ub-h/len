# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Shubham__ __Upadhyay__ <br> Desired Occupation - Data Scientist

# %% [markdown]
# _I am interested in data science because I want a job role as a Data Scientist. I really love analysing and working with data._

# %% [markdown]
# <h3> The following code will greet the user whose name is called.

# %%
def greet(name):
    print('Hello {}!'.format(name))
greet("IBM")
# Out:
# Hello IBM!

# %% [markdown]
# I'm glad to do this task <br>
# *  Making all these different cells.
# *  & learning new things to do. <br>
# You can visit IBM Website by clicking this blue link - __[IBM](https://www.ibm.com/)__ <br>
# ~I hope this works~<br>
